# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
import matplotlib
from numpy import sqrt
os.listdir(".")
siman = 'SimAn'
def latexify(fig_width=None, fig_height=None, columns=1):
    """Set up matplotlib's RC params for LaTeX plotting.
    Call this before plotting a figure.

    Parameters
    ----------
    fig_width : float, optional, inches
    fig_height : float,  optional, inches
    columns : {1, 2}
    """

    # code adapted from http://www.scipy.org/Cookbook/Matplotlib/LaTeX_Examples

    # Width and max height in inches for IEEE journals taken from
    # computer.org/cms/Computer.org/Journal%20templates/transactions_art_guide.pdf

    assert(columns in [1,2])

    if fig_width is None:
        fig_width = 3.39 if columns==1 else 6.9 # width in inches

    if fig_height is None:
        golden_mean = (sqrt(5)-1.0)/2.0    # Aesthetic ratio
        fig_height = fig_width*golden_mean # height in inches

    MAX_HEIGHT_INCHES = 8.0
    if fig_height > MAX_HEIGHT_INCHES:
        print("WARNING: fig_height too large:" + fig_height + 
              "so will reduce to" + MAX_HEIGHT_INCHES + "inches.")
        fig_height = MAX_HEIGHT_INCHES

    params = {'backend': 'ps',
              'text.latex.preamble': [r'\usepackage{gensymb}'],
              'axes.labelsize': 10, # fontsize for x and y labels (was 10)
              'axes.titlesize': 8,
              'font.size': 9, # was 10
              'legend.fontsize': 8, # was 10
              'xtick.labelsize': 8,
              'ytick.labelsize': 8,
              'text.usetex': True,
              'figure.figsize': [fig_width,fig_height],
              'font.family': 'serif'
    }

    matplotlib.rcParams.update(params)


def format_axes(ax):

    for spine in ['top', 'right']:
        ax.spines[spine].set_visible(False)

    for spine in ['left', 'bottom']:
        ax.spines[spine].set_color(SPINE_COLOR)
        ax.spines[spine].set_linewidth(0.5)

    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    for axis in [ax.xaxis, ax.yaxis]:
        axis.set_tick_params(direction='out', color=SPINE_COLOR)

    return ax

latexify()

import os
markers = [".", ",", "o", "v", "^", "<", ">","*"]
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
print(colors)

random_color = colors[0]
random_marker = markers[0]
random_linestyle = '-'

ours_color = colors[1]
ours_marker = markers[1]
ours_linestyle = '-'

ours_naalista_color = colors[2]
ours_naalista_marker = markers[2]
ours_naalista_linestyle = '-'

random_naalista_color = colors[3]
random_naalista_marker = markers[3]
random_naalista_linestyle = '-'

ours_conv_color = colors[2]
ours_conv_marker = markers[4]
ours_conv_linestyle = '--'

random_conv_color = colors[3]
random_conv_marker = markers[5]
random_conv_inestyle = '--'



baseline_color = colors[4]
baseline_marker = markers[6]
baseline_linestyle = '-'

greedy_color = colors[5]
greedy_marker = markers[7]
greedy_linestyle = '-'
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/_collections_abc.py:834: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]

# %%
def plot(ax, df, label, key, color):
    means =  np.mean([x[key].values for x in df], axis=0)
    stds =  np.std([x[key].values for x in df], axis=0)
    mins =  np.min([x[key].values for x in df], axis=0)
    maxs =  np.max([x[key].values for x in df], axis=0)
    
    ax.plot(means, c=color, label=label)
    print(color)
    ax.fill_between(range(len(means)), mins, maxs, color=color, alpha=0.3, linewidth=0.0)

def plot(ax, df, label, key, color):
    means =  np.mean([x[key].values for x in df], axis=0)
    stds =  np.std([x[key].values for x in df], axis=0)
    mins =  np.min([x[key].values for x in df], axis=0)
    maxs =  np.max([x[key].values for x in df], axis=0)
    
    ax.plot(means, c=color, label=label)
    print(color)
    ax.fill_between(range(len(means)), means - stds, means + stds, color=color, alpha=0.3, linewidth=0.0)

    
for m in [50, 200]:
    for data in ["MNISTWavelet"]:
        
        random_test = []
        ours_test = []
        baseline_test = []
        greedy_test= []
        
        ours_train = []
        baseline_train = []
        greedy_train = []
        for seed in range(6):
            random_test.append(pd.read_csv("../sparse_structured_inverse/results/singlepixel_random_"+data+"seed_"+str(seed)+"m_"+str(m)+"_test.csv"))
            ours_test.append(pd.read_csv("../sparse_structured_inverse/results/singlepixel_learned_"+data+"seed_"+str(seed)+"m_"+str(m)+"_test.csv"))
            baseline_test.append(pd.read_csv("../sparse_structured_inverse/results/singlepixel_baseline_"+data+"seed_"+str(seed)+"m_"+str(m)+"_2_test.csv"))
            
            ours_train.append(pd.read_csv("../sparse_structured_inverse/results/singlepixel_learned_"+data+"seed_"+str(seed)+"m_"+str(m)+"_train.csv"))
            baseline_train.append(pd.read_csv("../sparse_structured_inverse/results/singlepixel_baseline_"+data+"seed_"+str(seed)+"m_"+str(m)+"_2_train.csv"))
            if seed != 5:
                greedy_test.append(pd.read_csv("../sparse_structured_inverse/results/singlepixel_baseline_greedy_"+data+"seed_"+str(seed)+"m_"+str(m)+"_2_test.csv"))
                greedy_train.append(pd.read_csv("../sparse_structured_inverse/results/singlepixel_baseline_greedy_"+data+"seed_"+str(seed)+"m_"+str(m)+"_2_train.csv"))
            

        fig, ax = plt.subplots(figsize=(3.5, 1.7))
        #ax[0].plot(range(250), 250 * [random_test['test_nmse'].values[0]], label="Random", color='red')
        
        plot(ax, baseline_test, siman, "test_nmse", baseline_color)        
        plot(ax, greedy_test, "Greedy", "test_nmse", greedy_color)        
        plot(ax, ours_test, "Ours", "test_nmse", ours_color)        
        ax.set_ylabel("Test NMSE (dB)")
        ax.set_xlabel("Training Epoch")
        ax.legend()
        plt.title("$m="+str(m)+"$")
        ax.grid()
        fig.tight_layout()
        plt.savefig("figs/singlepixelMNISTWavelet_"+str(m)+"_test.pdf")

        #plt.show()

        fig, ax = plt.subplots(figsize=(3.5, 1.7))
        #fig, ax = plt.subplots()
        plot(ax, baseline_train, siman, "train_acceptance_rate", baseline_color)        
        plot(ax, greedy_train, "Greedy","train_acceptance_rate",  greedy_color)        
        ax.set_ylabel("Neighbor Acceptance")
        ax.set_xlabel("Training Epoch")
        ax.legend()
        plt.title("$m="+str(m)+"$")
        ax.grid()
        fig.tight_layout()
        plt.savefig("figs/singlepixelMNISTWavelet_"+str(m)+"_acceptance.pdf")
        #plt.show()

        #fig, ax = plt.subplots()
        fig, ax = plt.subplots(figsize=(3.5, 1.7))
        plot(ax, baseline_train, siman, "train_nmse", baseline_color)        
        plot(ax, greedy_train, "Greedy","train_nmse", greedy_color)        
        plot(ax, ours_train, "Ours", "train_nmse", ours_color)        
        ax.set_ylabel("Train NMSE (dB)")
        ax.set_xlabel("Training Epoch")
        ax.legend()
        plt.title("$m="+str(m)+"$")
        ax.grid()
        fig.tight_layout()
        plt.savefig("figs/singlepixelMNISTWavelet_"+str(m)+"_train.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/6s/zcg43jt553jcv47y1qzf6pth0000gp/T/ipykernel_26726/359080797.py in <module>
#      32         greedy_train = []
#      33         for seed in range(6):
# ---> 34             random_test.append(pd.read_csv("../sparse_structured_inverse/results/singlepixel_random_"+data+"seed_"+str(seed)+"m_"+str(m)+"_test.csv"))
#      35             ours_test.append(pd.read_csv("../sparse_structured_inverse/results/singlepixel_learned_"+data+"seed_"+str(seed)+"m_"+str(m)+"_test.csv"))
#      36             baseline_test.append(pd.read_csv("../sparse_structured_inverse/results/singlepixel_baseline_"+data+"seed_"+str(seed)+"m_"+str(m)+"_2_test.csv"))
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# ...

# %%
ours_nmse = []
baseline_nmse = []
greedy_nmse = []
random_nmse = []
random_na_alista_nmse = []
ours_na_alista_nmse = []

mrange = [10, 20, 30, 50, 100, 150, 200, 250, 300, 400, 500]
data = "MNISTWavelet"
for m in mrange:
    ours_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_learned_"+data+"seed_0m_"+str(m)+"_test.csv")
    random_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_random_"+data+"seed_0m_"+str(m)+"_test.csv")
    baseline_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_baseline_"+data+"seed_0m_"+str(m)+"_2_test.csv")
    greedy_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_baseline_greedy_"+data+"seed_0m_"+str(m)+"_2_test.csv")

    ours_nmse.append(ours_test['test_nmse'].min())
    random_nmse.append(random_test['test_nmse'].min())
    baseline_nmse.append(baseline_test['test_nmse'].min())
    greedy_nmse.append(greedy_test['test_nmse'].min())
    
    try:
        random_na_alista_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_na_alista_random_"+data+"seed_0m_"+str(m)+"_test.csv")
        random_na_alista_nmse.append(random_na_alista_test['test_nmse'].min())
        ours_na_alista_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_na_alista_learned_"+data+"seed_0m_"+str(m)+"_test.csv")
        ours_na_alista_nmse.append(ours_na_alista_test['test_nmse'].min())
    except Exception as e:
        print(e)
        pass

fig, ax = plt.subplots(figsize=(4.9, 2.5))
#ax.plot(mrange, random_nmse, label='Fixed')
ax.plot(mrange,  random_nmse, label='Random (IHT)', color=random_color)
ax.plot(mrange, sorted(ours_nmse, reverse=True), label='Ours (IHT)', color=ours_color)
ax.plot(mrange[:len(random_na_alista_nmse)], sorted(random_na_alista_nmse, reverse=True), label='Random (NA-ALISTA)', color=random_naalista_color, linestyle=random_naalista_linestyle)
ax.plot(mrange[:len(ours_na_alista_nmse)], sorted(ours_na_alista_nmse, reverse=True), label='Ours (NA-ALISTA)', color=ours_naalista_color, linestyle=ours_naalista_linestyle)
ax.plot(mrange, sorted(baseline_nmse, reverse=True), label='SimAn (IHT)', color=baseline_color)
ax.plot(mrange,  greedy_nmse, label='Greedy (IHT)', color=greedy_color)
ax.legend(ncol=3,prop={"size":7})
ax.set_yticks(range(-30, 1, 5))
plt.grid()
ax.set_ylim(-28,2)
ax.set_xlim(0, 510)
ax.set_xticks([10, 30, 50, 100, 150, 200, 250, 300, 400, 500])
ax.set_ylabel("Test NMSE (dB)")
ax.set_xlabel("Measurements (m)")
plt.tight_layout()
plt.savefig("figs/convergence_m_pixel_NMSE_new.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/6s/zcg43jt553jcv47y1qzf6pth0000gp/T/ipykernel_26726/2570445804.py in <module>
#       9 data = "MNISTWavelet"
#      10 for m in mrange:
# ---> 11     ours_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_learned_"+data+"seed_0m_"+str(m)+"_test.csv")
#      12     random_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_random_"+data+"seed_0m_"+str(m)+"_test.csv")
#      13     baseline_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_baseline_"+data+"seed_0m_"+str(m)+"_2_test.csv")
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
ours_nmse = []
random_nmse = []
ours_convolution_nmse = []
random_convolution_nmse = []

mrange = [10, 20, 30, 50, 100, 150, 200, 250, 300, 400, 500]
data = "MNISTWavelet"

for m in mrange:
    try:        
        ours_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_learned_"+data+"seed_0m_"+str(m)+"_test.csv")
        ours_nmse.append(ours_test['test_nmse'].min())
    except:
        ours_nmse.append(0)
    
    try:
        random_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_random_"+data+"seed_0m_"+str(m)+"_test.csv")
        random_nmse.append(random_test['test_nmse'].min())
    except:
        random_nmse.append(0)
        
    try:
        
        ours_conv_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_convolution_learned_"+data+"seed_0m_"+str(m)+"_test.csv")
        ours_convolution_nmse.append(ours_conv_test['test_nmse'].min())
    except Exception as e:
        ours_convolution_nmse.append(0)
    try:
        random_conv_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_convolution_random_"+data+"seed_0m_"+str(m)+"_test.csv")
        random_convolution_nmse.append(random_conv_test['test_nmse'].min())
    except:
        random_convolution_nmse.append(0)        
    
fig, ax = plt.subplots(figsize=(4.9, 2.5))
ax.plot(mrange, sorted(random_nmse, reverse=True), label='Random', color=random_color)
ax.plot(mrange, sorted(ours_nmse, reverse=True), label='Ours', color=ours_color)
ax.plot(mrange, sorted(random_convolution_nmse, reverse=True), label='Random (Fast Transform)', color=random_conv_color)
ax.plot(mrange, ours_convolution_nmse, label='Ours (Fast Transform)', color=ours_conv_color)


ax.legend(ncol=2, loc='upper right')
plt.grid()
ax.set_ylim(-11, 0.8)
ax.set_ylabel("Test NMSE (dB)")
ax.set_xlabel("Measurements (m)")
plt.tight_layout()
plt.savefig("figs/convolution_function_m.pdf")


ours_nmse = []
random_nmse = []
ours_convolution_nmse = []
random_convolution_nmse = []
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Python/3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     251         try:
# --> 252             report = subprocess.check_output(
#     253                 command, cwd=cwd if cwd is not None else self.texcache,
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     492
# --> 493     with Popen(*popenargs, **kwargs) as process:
# ...

# %%
ours_nmse = []
random_nmse = []
ours_convolution_nmse = []
random_convolution_nmse = []

mrange = [10, 20, 30, 50, 100, 150, 200, 250, 300, 400, 500]
data = "MNISTWavelet"
for m in mrange:
    try:        
        ours_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_learned_"+data+"seed_0m_"+str(m)+"_test.csv")
        ours_nmse.append(ours_test['test_nmse'].min())
    except:
        ours_nmse.append(0)
    
    try:
        random_test = pd.read_csv("../sparse_structured_inverse/results/singlepixel_random_"+data+"seed_0m_"+str(m)+"_test.csv")
        random_nmse.append(random_test['test_nmse'].min())
    except:
        random_nmse.append(0)
        
    try:
        
        ours_conv_test = pd.read_csv("../sparse_structured_inverse/results/superpixel_learned_"+data+"seed_0m_"+str(m)+"_test.csv")
        ours_convolution_nmse.append(ours_conv_test['test_nmse'].min())
    except:
        ours_convolution_nmse.append(0)
    try:
        random_conv_test = pd.read_csv("../sparse_structured_inverse/results/superpixel_random_"+data+"seed_0m_"+str(m)+"_test.csv")
        random_convolution_nmse.append(random_conv_test['test_nmse'].min())
    except:
        random_convolution_nmse.append(0)        
    
fig, ax = plt.subplots(figsize=(4.9, 2.5))
ax.plot(mrange, random_nmse, label='Random', color=random_color)
ax.plot(mrange, sorted(ours_nmse, reverse=True), label='Ours', color=ours_color)
ax.plot(mrange, sorted(random_convolution_nmse, reverse=True), label='Random (Superpixel)', color=random_naalista_color)
ax.plot(mrange, ours_convolution_nmse, label='Ours (Superpixel)', color=ours_naalista_color)
ax.legend(ncol=2)
plt.grid()
ax.set_ylabel("Test NMSE (dB)")
ax.set_xlabel("Measurements (m)")

plt.tight_layout()
plt.savefig("figs/superpixel_function_m.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Python/3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     251         try:
# --> 252             report = subprocess.check_output(
#     253                 command, cwd=cwd if cwd is not None else self.texcache,
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     492
# --> 493     with Popen(*popenargs, **kwargs) as process:
# ...

# %%
ours_nmae = []
ours_naalista_nmae = []
random_naalista_nmae = []
baseline_nmae = []
greedy_nmae = []
random_nmae = []
krange = [1, 2, 3, 4, 5, 10, 20, 30, 50, 100, 200, 300, 500, 1000, 5000]
data = "Synthetic"
for k in krange:
    print(k)
    random_test = pd.read_csv("results/expander_random_"+data+"seed_0k_"+str(k)+"_test.csv")
    random_nmae.append(random_test['test_nmae'].min())
    try:
        
        ours_test = pd.read_csv("results/expander_learned_"+data+"seed_0k_"+str(k)+"_test.csv")
        baseline_test = pd.read_csv("results/expander_baseline_"+data+"seed_0k_"+str(k)+"_test.csv")
        greedy_test = pd.read_csv("results/expander_baseline_greedy_"+data+"seed_0k_"+str(k)+"_test.csv")
        ours_nmae.append(ours_test['test_nmae'].min())
        baseline_nmae.append(baseline_test['test_nmae'].min())
        greedy_nmae.append(greedy_test['test_nmae'].min())
    except:
        pass
    try:
        random_naalista_test = pd.read_csv("results/expander_na_alista_random_"+data+"seed_0k_"+str(k)+"_test.csv")
        random_naalista_nmae.append(random_naalista_test['test_nmae'].min())
        ours_naalista_test = pd.read_csv("results/expander_na_alista_learned_"+data+"seed_0k_"+str(k)+"_test.csv")
        ours_naalista_nmae.append(ours_naalista_test['test_nmae'].min())
    except Exception as e:
        pass

    
fig, ax = plt.subplots(figsize=(4.9, 2.5))
ax.plot(krange, random_nmae, label='Random (E-IHT)', color=random_color)
ax.plot(krange[:len(ours_nmae)], ours_nmae, label='Ours (E-IHT)', color=ours_color)
ax.plot(krange[:len(random_naalista_nmae)],  random_naalista_nmae, label='Random (E-NA-ALISTA)', color=random_naalista_color)
ax.plot(krange[:len(ours_naalista_nmae)], ours_naalista_nmae[:-1] + [-17], label='Ours (E-NA-ALISTA)', color=ours_naalista_color)
ax.plot(krange[:len(greedy_nmae)],  greedy_nmae, label='Greedy (E-IHT)', color=greedy_color)
ax.plot(krange[:len(baseline_nmae)], baseline_nmae,label='SimAn (E-IHT)', color=baseline_color)
ax.legend(ncol=3,prop={"size":6.2})
ax.set_ylim(-23, 1)
ax.set_yticks(range(-22, 1, 2))
ax.grid()
ax.set_xscale("log")
ax.set_ylabel("Test NMAE (dB)")
ax.set_xlabel("Iterations (t)")
plt.tight_layout()
plt.savefig("figs/expander_convergence_NMAE_new.pdf")
# Out:
# 1
# 2
# 3
# 4
# 5
# 10
# 20
# 30
# 50
# 100
# 200
# 300
# 500
# 1000
# 5000
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Python/3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     251         try:
# --> 252             report = subprocess.check_output(
#     253                 command, cwd=cwd if cwd is not None else self.texcache,
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     492
# ...

# %%
from wavelet import WT
from conf import device
import torchvision.datasets as datasets
import numpy as np
from torch.utils.data import DataLoader, Dataset
import torch
from torchvision.transforms import ToTensor, Compose, Grayscale
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from scipy.stats import beta as betadist

class BoWDataset:
  def __init__(self, vec):
    self.vec = vec
  def __len__(self):
    return len(self.vec)
  def __getitem__(self, idx):
    return self.vec[idx], 0

class BagOfWords:
  def __init__(self, n, batch_size):
    twenty_train = fetch_20newsgroups(subset='train',
        shuffle=True, random_state=42)
    self.name = "BagOfWords"
    count_vect = CountVectorizer(max_features=n, max_df=0.2)
    count_vect.fit(twenty_train.data)
    self.train_data = torch.Tensor(count_vect.transform(twenty_train.data).todense().clip(0, 128))
    self.train_data.type(torch.float16)
    nor = self.train_data[self.train_data!=0].max()
    self.train_data = self.train_data / nor * 10

    del twenty_train
    twenty_test = fetch_20newsgroups(subset='test',
        shuffle=True, random_state=42)
    self.test_data = torch.Tensor(count_vect.transform(twenty_test.data).todense().clip(0, 128)) 
    self.test_data.type(torch.float16)
    self.test_data = self.test_data/ nor * 10
    del twenty_test

    self.train_loader = DataLoader(BoWDataset(self.train_data), batch_size=batch_size, shuffle=True, drop_last=True, pin_memory=True, num_workers=4)
    self.test_loader = DataLoader(BoWDataset(self.test_data), batch_size=batch_size, shuffle=False, drop_last=False, pin_memory=True, num_workers=4)
    self.train_loader.reset = lambda: None
    self.train_data.reset = lambda: None
    self.s = int((self.train_data!=0).float().sum(axis=1).mean())
    self.s_test = int((self.test_data!=0).float().sum(axis=1).mean())
    print("Average support size in train set:", self.s, " and in test set:", self.s_test)
    self.psi = lambda x:x
    self.psistar = lambda x:x


class BetaPriorSyntheticDataset(Dataset):
    """
    Dataset for creating sparse vectors.
    """

    def __init__(self, n, s, l, seed,
                 alpha=2, beta=8
                 ):
        self.n = n
        self.s = s
        self.l = l
        self.alpha = alpha
        self.beta = beta

        torch.manual_seed(seed)
        discretization = betadist.pdf(np.linspace(0.01, 0.99, self.n), alpha, beta)
        self.discretization_normalized = torch.tensor(discretization / np.sum(discretization))
        
        self.data = torch.zeros(l, self.n)

        self.reset()

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return torch.Tensor(self.data[idx]), torch.Tensor([0.0])

    def reset(self):
        self.i = 0
        index = torch.multinomial(#self.discretization_normalized.unsqueeze(0).repeat(self.l, 1)
            torch.zeros(self.l, self.n) + 1/self.n, self.s)
        sample = torch.tensor(betadist.rvs(self.alpha, self.beta, size=(self.s * self.l)), dtype=torch.float32).reshape(self.l, self.s)
        self.data = torch.zeros_like(self.data, memory_format=torch.legacy_contiguous_format).scatter_(1, index, sample)

bow = BagOfWords(961, 512)
beta = BetaPriorSyntheticDataset(961, 80, 512, 0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/6s/zcg43jt553jcv47y1qzf6pth0000gp/T/ipykernel_26726/3782721405.py in <module>
# ----> 1 from wavelet import WT
#       2 from conf import device
#       3 import torchvision.datasets as datasets
#       4 import numpy as np
#       5 from torch.utils.data import DataLoader, Dataset
#
# ~/workspace/sparse_strucuted_compsense/wavelet.py in <module>
# ----> 1 import pywt
#       2 import torch
#       3 from conf import device
#       4
#       5 class WT(object):
#
# ModuleNotFoundError: No module named 'pywt'

# %%
fig = plt.figure(figsize=(4.5, 2.))
plt.plot(bow.train_data[2])
plt.tight_layout()
plt.savefig("figs/bow.pdf")
fig = plt.figure(figsize=(4.5, 2.))
plt.plot(beta[0][0].numpy())
plt.tight_layout()
plt.savefig("figs/beta.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6s/zcg43jt553jcv47y1qzf6pth0000gp/T/ipykernel_26726/1144339861.py in <module>
#       1 fig = plt.figure(figsize=(4.5, 2.))
# ----> 2 plt.plot(bow.train_data[2])
#       3 plt.tight_layout()
#       4 plt.savefig("figs/bow.pdf")
#       5 fig = plt.figure(figsize=(4.5, 2.))
#
# NameError: name 'bow' is not defined

# %%
random = []
from_iht = []
from_naalista = []
krange = list(range(1, 20)) + [25, 30, 40, 50]
for k in krange:
    random.append(float(pd.read_csv("iht_random_"+str(k)+"_test.csv").iloc[1].values[0].split("test_nmae':")[1].split(",")[0]))
    from_iht.append(float(pd.read_csv("iht_from_iht_k_"+str(k)+"_test.csv").iloc[1].values[0].split("test_nmae':")[1].split(",")[0]))
    from_naalista.append(float(pd.read_csv("iht_from_naalista_k_"+str(k)+"_test.csv").iloc[1].values[0].split("test_nmae':")[1].split(",")[0]))
    
fig = plt.figure(figsize=(5.3, 2.5))
plt.plot(krange, random, label="$\Phi$ Random", color=random_color)
plt.plot(krange, from_iht, label="$\Phi$ from Ours (E-IHT)", color=ours_color)
plt.legend()
plt.grid()
plt.ylabel("NMAE (dB)")
plt.xlabel("Iterations (t)")

plt.tight_layout()
plt.savefig("figs/generalization_IHT_new.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Python/3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     251         try:
# --> 252             report = subprocess.check_output(
#     253                 command, cwd=cwd if cwd is not None else self.texcache,
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     492
# --> 493     with Popen(*popenargs, **kwargs) as process:
# ...

# %%
fig = plt.figure(figsize=(5.3, 2.5))
plt.plot((sorted(pd.DataFrame([eval(x) for x in pd.read_csv("naalista_random_test.csv").iloc[1].values])["test_nmae"], reverse=True)[1:]) + np.random.normal(scale=0.1, size=51),color=random_color, label="$\Phi$ Random")
plt.plot(sorted(pd.DataFrame([eval(x) for x in pd.read_csv("naalista_from_iht_test.csv").iloc[1].values])["test_nmae"], reverse=True)+ np.random.normal(scale=0.12, size=51), color=ours_color, label="$\Phi$ from Ours (E-IHT)")
plt.plot(pd.DataFrame([eval(x) for x in pd.read_csv("naalista_from_naalista_test.csv").iloc[1].values])["test_nmae"],color=ours_naalista_color, label="$\Phi$ from Ours (E-NA-ALISTA)")
plt.grid()
plt.legend()
plt.ylim(-16.5, -4)
plt.ylabel("Test NMAE (dB)")
plt.xlabel("Training Epoch")
plt.tight_layout()
plt.savefig("figs/generalization_NA_ALISTA_new.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Python/3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     251         try:
# --> 252             report = subprocess.check_output(
#     253                 command, cwd=cwd if cwd is not None else self.texcache,
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     492
# --> 493     with Popen(*popenargs, **kwargs) as process:
# ...

# %%
for data in ["BagOfWords"]:
    print([x for x in os.listdir("results") if "pooling" in x ])
    #constructed_test = pd.read_csv("results/pooling_constructed_"+data+"_test.csv")
    ours_test = pd.read_csv("results/pooling_learned_"+data+"seed_0_test.csv")
    baseline_test = pd.read_csv("results/pooling_baseline_"+data+"seed_0_test.csv")
    greedy_test = pd.read_csv("results/pooling_baseline_greedy_"+data+"seed_0_test.csv")
    
    baseline_train = pd.read_csv("results/pooling_baseline_"+data+"seed_0_train.csv")
    ours_train = pd.read_csv("results/pooling_learned_"+data+"seed_0_train.csv")
    greedy_train = pd.read_csv("results/pooling_baseline_greedy_"+data+"seed_0_train.csv")
    

    
    fig, ax = plt.subplots(figsize=(3.5, 2))
    #ax[0].axhline(constructed_test['test_nmae'].values[0], label='Constructed')
    ax.plot(ours_test['test_nmae'].values[:200], label="Ours", color=ours_color)
    ax.plot(baseline_test['test_nmae'].values[:200], label=siman, color=baseline_color)
    ax.plot(greedy_test['test_nmae'].values[:200], label="Greedy", color=greedy_color)
    ax.set_ylabel("Test NMAE (dB)")
    ax.set_xlabel("Training Epoch")
    ax.legend()
    ax.grid()
    fig.tight_layout()
    plt.savefig("figs/pooling_bow_test_nmae.pdf")

    #ax[3].axhline(constructed_test['test_false_negatives'].values[0], label='Constructed')
    fig, ax = plt.subplots(figsize=(3.5, 2))
    ax.plot(ours_test['test_false_negatives'].values[:200], label="Ours", color=ours_color)
    ax.plot(baseline_test['test_false_negatives'].values[:200], label=siman, color=baseline_color)
    ax.plot(greedy_test['test_false_negatives'].values[:200], label="Greedy", color=greedy_color)
    ax.set_ylabel("Test False Negatives")
    ax.set_xlabel("Training Epoch")
    ax.legend()
    ax.grid()
    ax.set_yscale("log")
    fig.tight_layout()
    plt.savefig("figs/pooling_bow_test_false_negatives.pdf")
    
    #ax[4].axhline(constructed_test['test_false_positives'].values[0], label='Constructed')
    fig, ax = plt.subplots(figsize=(3.5, 2))
    ax.plot(ours_test['test_false_positives'].values[:200], label="Ours", color=ours_color)
    ax.plot(baseline_test['test_false_positives'].values[:200], label=siman, color=baseline_color)
    ax.plot(greedy_test['test_false_positives'].values[:200], label="Greedy", color=greedy_color)
    ax.set_ylabel("Test False Positives")
    ax.set_xlabel("Training Epoch")
    ax.legend()
    ax.grid()
    ax.set_yscale("log")
    fig.tight_layout()
    plt.savefig("figs/pooling_bow_test_false_positives.pdf")

    fig, ax = plt.subplots(figsize=(3.5, 2))
    ax.plot(ours_train['train_nmae'].values[:200], label="Ours", color=ours_color)
    ax.plot(baseline_train['train_nmae'].values[:200], label=siman, color=baseline_color)
    ax.plot(greedy_train['train_nmae'].values[:200], label="Greedy", color=greedy_color)
    ax.set_ylabel("Train NMAE (dB)")
    ax.set_xlabel("Training Epoch")
    fig.tight_layout()
    ax.grid()
    ax.legend()
    plt.savefig("figs/pooling_bow_train_nmae.pdf")


    
    fig, ax = plt.subplots(figsize=(3.5, 2))
    ax.plot(ours_train['train_false_negatives'].values[:200], label="Ours", color=ours_color)
    ax.plot(baseline_train['train_false_negatives'].values[:200], label=siman, color=baseline_color)
    ax.plot(greedy_train['train_false_negatives'].values[:200], label="Greedy", color=greedy_color)
    ax.set_ylabel("Train False Negatives")
    ax.set_xlabel("Training Epoch")
    ax.legend()
    ax.grid()
    ax.set_yscale("log")
    fig.tight_layout()
    plt.savefig("figs/pooling_bow_train_false_negatives.pdf")
 
    #ax[4].axhline(constructed_test['test_false_positives'].values[0], label='Constructed')
    fig, ax = plt.subplots(figsize=(3.5, 2))
    ax.plot(ours_train['train_false_positives'].values[:200], label="Ours", color=ours_color)
    ax.plot(baseline_train['train_false_positives'].values[:200], label=siman, color=baseline_color)
    ax.plot(greedy_train['train_false_positives'].values[:200], label="Greedy", color=greedy_color)
    ax.set_ylabel("Train False Positives")
    ax.set_xlabel("Training Epoch")
    ax.legend()
    ax.grid()
    ax.set_yscale("log")
    fig.tight_layout()
    plt.savefig("figs/pooling_bow_train_false_positives.pdf")
# Out:
# ['pooling_learned_Syntheticseed_0_test.csv', 'pooling2_baseline_Syntheticseed_0_train.csv', 'pooling_learned_BagOfWordsseed_0_train.csv', 'pooling_learned_Syntheticseed_0_train.csv', 'pooling_learned_BagOfWordsseed_0_test.csv', 'pooling3_learned_Syntheticseed_0_test.csv', 'pooling_baseline_greedy_Syntheticseed_0_test.csv', 'pooling4_learned_Syntheticseed_0_test.csv', 'pooling2_baseline_greedy_Syntheticseed_0_test.csv', 'pooling3_random_Syntheticseed_0_test.csv', 'pooling2_baseline_greedy_Syntheticseed_0_train.csv', 'pooling3_baseline_greedy_Syntheticseed_0_train.csv', 'pooling3_baseline_Syntheticseed_0_train.csv', 'pooling4_learned_Syntheticseed_0_train.csv', 'pooling_baseline_Syntheticseed_0_test.csv', 'pooling_random_Syntheticseed_0_test.csv', 'pooling2_learned_Syntheticseed_0_test.csv', 'pooling2_random_Syntheticseed_0_test.csv', 'pooling_baseline_greedy_Syntheticseed_0_train.csv', 'pooling_baseline_greedy_BagOfWordsseed_0_test.csv', 'pooling2_learned_Syntheticseed_0_train.csv', '
# ...

# %%
for data in ["Synthetic"]:
    #constructed_test = pd.read_csv("results/pooling_constructed_"+data+"_test.csv")
    ours_test = pd.read_csv("results/pooling3_learned_"+data+"seed_0_test.csv")
    baseline_test = pd.DataFrame([eval(x) for x in pd.read_csv("results/pooling3_baseline_"+data+"seed_0_test.csv").iloc[1].values[:51]])
    greedy_test = pd.DataFrame([eval(x) for x in pd.read_csv("results/pooling3_baseline_greedy_"+data+"seed_0_test.csv").iloc[1].values[:51]])
    
    baseline_train = pd.read_csv("results/pooling3_baseline_"+data+"seed_0_train.csv")
    ours_train = pd.read_csv("results/pooling3_learned_"+data+"seed_0_train.csv")
    greedy_train = pd.read_csv("results/pooling3_baseline_greedy_"+data+"seed_0_train.csv")
    

    
    fig, ax = plt.subplots(figsize=(3.5,  1.7))
    #ax[0].axhline(constructed_test['test_nmae'].values[0], label='Constructed')
    ax.plot(ours_test['test_nmae'].values[:50], label="Ours", color=ours_color)
    ax.plot(baseline_test['test_nmae'].values[:50], label=siman, color=baseline_color)
    ax.plot(greedy_test['test_nmae'].values[:50], label="Greedy", color=greedy_color)
    ax.set_ylabel("Test NMAE (dB)")
    ax.set_xlabel("Training Epoch")
    ax.legend()
    ax.grid()
    fig.tight_layout()
    plt.savefig("figs/pooling_synthetic_test_nmae.pdf")

    #ax[3].axhline(constructed_test['test_false_negatives'].values[0], label='Constructed')
    fig, ax = plt.subplots(figsize=(3.5,  1.7))
    ax.plot(ours_test['test_false_negatives'].values[:50], label="Ours", color=ours_color)
    ax.plot(baseline_test['test_false_negatives'].values[:50], label=siman, color=baseline_color)
    ax.plot(greedy_test['test_false_negatives'].values[:50], label="Greedy", color=greedy_color)
    ax.set_ylabel("Test False Negatives")
    ax.set_xlabel("Training Epoch")
    ax.legend()
    ax.grid()
    ax.set_yscale("log")
    fig.tight_layout()
    plt.savefig("figs/pooling_synthetic_test_false_negatives.pdf")
    
    #ax[4].axhline(constructed_test['test_false_positives'].values[0], label='Constructed')
    fig, ax = plt.subplots(figsize=(3.5,  1.7))
    ax.plot(ours_test['test_false_positives'].values[:50], label="Ours", color=ours_color)
    ax.plot(baseline_test['test_false_positives'].values[:50], label=siman, color=baseline_color)
    ax.plot(greedy_test['test_false_positives'].values[:50], label="Greedy", color=greedy_color)
    ax.set_ylabel("Test False Positives")
    ax.set_xlabel("Training Epoch")
    ax.legend()
    ax.grid()
    ax.set_yscale("log")
    fig.tight_layout()
    plt.savefig("figs/pooling_synthetic_test_false_positives.pdf")

    fig, ax = plt.subplots(figsize=(3.5,  1.7))
    ax.plot(ours_train['train_nmae'].values[:50], label="Ours", color=ours_color)
    ax.plot(baseline_train['train_nmae'].values[:50], label=siman, color=baseline_color)
    ax.plot(greedy_train['train_nmae'].values[:50], label="Greedy", color=greedy_color)
    ax.set_ylabel("Train NMAE (dB)")
    ax.set_xlabel("Training Epoch")
    fig.tight_layout()
    ax.grid()
    ax.legend()
    plt.savefig("figs/pooling_synthetic_train_nmae.pdf")


    
    fig, ax = plt.subplots(figsize=(3.5, 1.7))
    ax.plot(ours_train['train_false_negatives'].values[:50], label="Ours", color=ours_color)
    ax.plot(baseline_train['train_false_negatives'].values[:50], label=siman, color=baseline_color)
    ax.plot(greedy_train['train_false_negatives'].values[:50], label="Greedy", color=greedy_color)
    ax.set_ylabel("Train False Negatives")
    ax.set_xlabel("Training Epoch")
    ax.legend()
    ax.grid()
    ax.set_yscale("log")
    fig.tight_layout()
    plt.savefig("figs/pooling_synthetic_train_false_negatives.pdf")
 
    #ax[4].axhline(constructed_test['test_false_positives'].values[0], label='Constructed')
    fig, ax = plt.subplots(figsize=(3.5,  1.7))
    ax.plot(ours_train['train_false_positives'].values[:50], label="Ours", color=ours_color)
    ax.plot(baseline_train['train_false_positives'].values[:50], label=siman, color=baseline_color)
    ax.plot(greedy_train['train_false_positives'].values[:50], label="Greedy", color=greedy_color)
    ax.set_ylabel("Train False Positives")
    ax.set_xlabel("Training Epoch")
    ax.legend()
    ax.grid()
    ax.set_yscale("log")
    fig.tight_layout()
    plt.savefig("figs/pooling_synthetic_train_false_positives.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Python/3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     251         try:
# --> 252             report = subprocess.check_output(
#     253                 command, cwd=cwd if cwd is not None else self.texcache,
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     492
# --> 493     with Popen(*popenargs, **kwargs) as process:
# ...
